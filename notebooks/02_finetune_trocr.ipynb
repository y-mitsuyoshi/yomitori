# %% [markdown]
# # 02 — TrOCR学習の対話型実行
#
# 合成データでTrOCRをファインチューニングします。

# %%
import sys; sys.path.insert(0, '..')
from training.train_trocr import main as train_main
import argparse

# This is a placeholder; run training via CLI instead:
# python -m training.train_trocr --data_dir data/synthetic/driver_license/ --epochs 5
