# %% [markdown]
# # 03 — E2E精度評価
#
# パイプライン全体の精度を評価します。

# %%
import sys; sys.path.insert(0, '..')
import cv2, json
from src.cli import build_registry
from src.pipeline.ocr_engine import OCREngine
# Placeholder: run inference on sample images and compute field-level accuracy.
