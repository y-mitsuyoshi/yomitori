# %% [markdown]
# # 01 — 前処理の可視化・デバッグ
#
# このノートブックではホモグラフィ補正・二値化の各ステップを可視化します。

# %%
import sys; sys.path.insert(0, '..')
import cv2
import numpy as np
from src.preprocessing.homography import HomographyCorrector
from src.utils.image_utils import visualize_preprocessing

image = cv2.imread('../data/samples/sample_license.jpg')
if image is not None:
    corrector = HomographyCorrector(target_size=(2400, 1512))
    corrector.visualize(image)
else:
    print('Place a sample image at data/samples/sample_license.jpg')
